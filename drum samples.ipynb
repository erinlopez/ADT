# %%
import os
import import_ipynb
from Drums import *
# Out:
# importing Jupyter notebook from Drums.ipynb

# %%
lst = ['drumsdataset/kick', 'drumsdataset/overheads', 'drumsdataset/snare', 'drumsdataset/toms']
for directory in lst:
    for filename in os.listdir(directory):
        if filename.endswith('.wav'):
            file = (f"{directory}/{filename}")
            sample = Drums(file)
            sample.melsave(imgdir = 'drumsdataset/mel_img/', filename = filename)
